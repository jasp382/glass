# %% [markdown]
# # OSM File to PSQL DB

# %%
from glass.it.db import osm_to_psql

inOsm = '/mnt/d/geopark26/dados_anac/osm_pnse.pbf'
out_db = 'osm_pnse3'

osm_to_psql(inOsm, out_db, schema='osm_data')

# %% [markdown]
# # OSM File to PSQL DB

# %%
from glass.it.db import osm_to_psql
from glass.pys.oss import lst_ff, fprop

in_f = '/mnt/x/autoclsosm_gab/osmdata/portugal-latest.osm.pbf'

osm_db = 'osm_pt'

ff = '.pbf'

osm_to_psql(in_f, osm_db)

# %% [markdown]
# # Convert OSM data into Feature Class #

# %%
from glass.it.osm import osm_to_featcls
from glass.pys.oss import lst_ff
import os

ifolder = '/mnt/d/a2land2023/osmdata'
osmfiles = lst_ff(ifolder, file_format='.xml')

for osm in osmfiles:
    osm_to_featcls(osm, os.path.dirname(osm), useXmlName=True, outepsg=3763)

# %%
from glass.it.osm import osm_to_featcls
import os

osm = '/mnt/x/autoclsosm_tk1/osmfiles/osm_porto.pbf'

osm_to_featcls(osm, os.path.dirname(osm), useXmlName=True, outepsg=3763)

# %%
from glass.it.osm import osm_to_gpkg

osm  = '/mnt/c/geosciv/dados_base/osm/osm_coimbra.pbf'
gpkg = '/mnt/c/geosciv/dados_base/osm/osm_coimbra.gpkg'

osm_to_gpkg(osm, gpkg, oepsg=3763)
