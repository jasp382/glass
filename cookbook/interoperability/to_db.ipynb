# %%
from glass.it.db import shp_to_psql

shp = '/mnt/x/autoclsosm_tk2/osmautocls_tk2.gdb'

lyrs = {'/mnt/x/autoclsosm_tk2/osmautocls_tk2.gdb' : 'pt_poly'}

db = 'osm_pt_poly'

shp_to_psql(db, shp, srs=3763, api="ogr2ogr", lyrname=lyrs)
