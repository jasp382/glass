# %% [markdown]
# ### Topology correction

# %%
from glass.gp.cln import fix_geom_topo

ishp = '/mnt/x/autoclsosm_tk1/osmfiles/osm_coimbra_poly.shp'

oshp = '/mnt/x/autoclsosm_tk1/osmfiles/osm_coimbra_poly_v3.shp'

fix_geom_topo(ishp, oshp, api='psql')

# %%
ishp = '/mnt/x/autoclsosm_tk1/osm/osm_porto_poly.shp'

oshp = '/mnt/x/autoclsosm_tk1/osm/osm_porto_poly_v2.shp'

eshp = '/mnt/x/autoclsosm_tk1/osm/osm_porto_poly_errors.shp'

from glass.gp.cln import rm_geom_errors

rm_geom_errors(ishp, oshp, eshp)
