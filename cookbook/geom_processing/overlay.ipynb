# %% [markdown]
# ### Clip Feature Class using as clip features each file of one folder

# %%
in_shp = '/mnt/disk1/jasp/dgtinescc/urbanosm_v1_diss.shp'

clipshps = '/mnt/disk1/jasp/dgtinescc/refgrid'

outfolder = '/mnt/disk1/jasp/dgtinescc/osmurbanv1'

bname = 'uosmv1'

from glass.gp.ovl.clipp import clipshp_shpinfolder

clipshp_shpinfolder(in_shp, clipshps, outfolder, bname=bname)

# %% [markdown]
# ### Clip Feature Class using as clip features each feature of other feature class

# %%
clip_shp = '/mnt/x/rms/res24/mun_v0.shp'

clip_id  = 'idmun'

infeat = '/mnt/x/rms/lulc/rms24_evus.shp'

ofolder = '/mnt/x/rms/green'

bname = 'mun'

from glass.dtt.split import split_shp_by_attr
from glass.gp.ovl.clipp import clipshp_shpinfolder

_clipfeats = split_shp_by_attr(clip_shp, clip_id, ofolder, valinname=True, outname='mun')
clipshp_shpinfolder(infeat, ofolder, ofolder, bname='evus')

# %% [markdown]
# ### Intersect each shape in ishps with each shape in intshp
#
# ESRI stuff

# %%
ishps = [
    'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/class_obj',
    #'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/train_artificial',
    #'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/train_evu',
    #'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/train_resi',
    #'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/train_trees'
]

intshp = [
    #'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/osm_poly',
    'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/osm_lines',
    'C:/Users/jptz9/Documents/ArcGIS/Projects/autoclsosm__tk1/autoclsosm__tk1.gdb/osm_points'
]

import os
from glass.pys.oss import fprop
from glass.esri.gp.ovl import intersection

for shp in ishps:
    name = fprop(shp, 'fn')
    f = os.path.dirname(shp)
    for ishp in intshp:
        _name = fprop(ishp, 'fn')
        
        intersection([shp, ishp], os.path.join(f, f'{name}_{_name}'))
