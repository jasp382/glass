# %%
from glass.ete.mob.cstsurf import mk_costsuf

# %%
dem = '/home/jasp/acc_rst/norte/ext_norte.tif'

lulc = '/home/jasp/acc_rst/norte/cosc21_norte_sec.shp'

lutime = 'minkm'

rdv = '/home/jasp/acc_rst/norte/rdv_norte.shp'
rdvcol = None

barr = '/home/jasp/acc_rst/norte/barr_norte_vf.shp'

out = '/home/jasp/acc_rst/norte/scost_norte.tif'

# %%
mk_costsuf(dem, lulc, lutime, rdv, rdvcol, barr, out, dissolve_lu=None)
