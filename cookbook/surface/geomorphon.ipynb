# %%
dem = '/home/jasp/autoclsosm/dem_coimbra.tif'

out = '/home/jasp/autoclsosm/geomorf_coimbra.tif'

method = 'geomorphon'
#method = 'paramscale'

from glass.rst.surf.terrain import geomorphometry

geomorphometry(dem, out, meth=method)
