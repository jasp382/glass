# %% [markdown]
# ## Count how many times a region appears in a set of ESRI Shapefiles

# %%
from glass.rst.stats import count_region_in_shape

# %%
in_folder = '/mnt/x/pwgis/tpalunos/aa_geopark/'

ref = '/mnt/x/pwgis/tpalunos/surface/dem_geopark.tif'

out = '/mnt/x/pwgis/tpalunos/burncount.tif'

# %%
count_region_in_shape(in_folder, ref, out, returnprob=None)

# %% [markdown]
# ## Get Statistics for each feature in vec

# %%
vec = '/mnt/x/rms/res24/azores_freg_v4.shp'

col = 'no2s5p'
meth = 'average'
rst = '/mnt/x/rms/no2/no2021_azores.tif'

outvec = '/mnt/x/rms/res24/azores_freg_v5.shp'

from glass.rst.zon import rst_stats_eachfeat

rst_stats_eachfeat(vec, rst, col, meth, outvec)
