# %%
from glass.dtt.tbl import cols_to_rows

intbl = 'X:/conv_freguesias/conversao_freg.xlsx'
otbl = 'X:/conv_freguesias/conversao_freg_v2.xlsx'

iid = 'novo_dicofre'

cols = ["dicofre1", "dicofre2", "dicofre3", "dicofre4", "dicofre5", "dicofre6", "dicofre7"]

colsname = "dicofre"
valcol = "oldfreg"

sheet = 'relacao_freg_v1'

cols_to_rows(intbl, iid, cols, colsname, valcol, otbl, sheet=sheet)
