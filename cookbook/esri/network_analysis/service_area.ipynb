# %%
nds = {
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_driving'  : 'DrivingMode',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk3kph' : 'Walking',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk4kph' : 'Walking',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk5kph' : 'Walking',
}

out = {
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_driving'  : 'X://blinc_acc/blinc.gdb/isocronas/ugsiso_driving',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk3kph' : 'X://blinc_acc/blinc.gdb/isocronas/ugsiso_walk3kph',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk4kph' : 'X://blinc_acc/blinc.gdb/isocronas/ugsiso_walk4kph',
    'X://blinc_acc/rdv2025.gdb/coimbra/nd_cmb_walk5kph' : 'X://blinc_acc/blinc.gdb/isocronas/ugsiso_walk5kph',
}

facilities = 'X://blinc_acc/evus/ugs_points.shp'

tbreaks = [i for i in range(1, 61)] + [120]

# %%
from glass.esri.mob.na import service_area

# %%
tbreaks

# %%
for nd in nds:
    service_area(
        nd, tbreaks, facilities, out[nd],
        overlap="dissolve",
        impedance=nds[nd],
        to_facility=True,
        detailed=None
    )
