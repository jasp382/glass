# %%
xyr = {'y': 38.71230412063501, 'x': -9.141483306884767, 'r': 2892.8435901939315}

# %%
from glass.adv.dsn.fb import places_by_query

fb_places = places_by_query(xyr, 4326, epsgOut=3857)
# Out:
#                                                 about  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  GNR - UMA FORÃ‡A HUMANA, PRÃ“XIMA E DE CONFIANÃ‡A...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
print fb_places

# %%
print fb_places.columns.values

# %%
print fb_places[u'description']
